# %%
import spotipy
import spotipy.util as util
import json
from account import *
from datetime import datetime
from utils import *



token = util.prompt_for_user_token(username='ohht10004@gmail.com',
                                   scope=scopes,
                                   client_id=id,
                                   client_secret=pw,
                                   redirect_uri=uri)

if token:
    sp = spotipy.Spotify(auth=token)
    result = sp.current_user_recently_played()

saving = []
temp = []
for instance in result['items']:

    temp.append({'Played_Time' : change_to_korea_time(instance['played_at']),
                 'Song_name' : instance['track']['name'],
                 'Artist' : instance['track']['artists'][0]['name'],
                 'Length' : instance['track']['duration_ms']//1000,
                 'Genres' : get_genre(instance['track']['artists'][0]['id'], sp)})
                 #노래 장르 검색하는 방법 찾기 -> 노래에 대한 장르는 없고, 가수의 장르를 검색해야할듯

# %%
temp
# Out:
# [{'Played_Time': datetime.datetime(2023, 3, 20, 21, 28, 37, 358000),
#   'Song_name': 'まちがいさがし',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 267,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 21, 24, 9, 717000),
#   'Song_name': 'Lemon',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 255,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 21, 19, 53, 700000),
#   'Song_name': '優しい人',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 208,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 21, 16, 25, 221000),
#   'Song_name': '馬と鹿',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 265,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 21, 11, 59, 535000),
#   'Song_name': 'パプリカ',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 202,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 21, 8, 37, 116000),
#   'Song_name': 'PLACEBO + 野田洋次郎',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 240,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 21, 4, 36, 359000),
#   'Song_name': '感電',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 264,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 21, 0, 12, 314000),
#   'Song_name': 'Flamingo',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 196,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 20, 56, 55, 891000),
#   'Song_name': 'カムパネルラ',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 235,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 20, 52, 59, 423000),
#   'Song_name': 'M八七',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 263,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 20, 48, 35, 320000),
#   'Song_name': 'LOSER',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 243,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 20, 37, 41, 480000),
#   'Song_name': '死神',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 180,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 20, 34, 22, 329000),
#   'Song_name': '感電',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 264,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 20, 9, 48, 35000),
#   'Song_name': '死神',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 180,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 20, 6, 47, 319000),
#   'Song_name': 'アイネクライネ',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 288,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 20, 1, 58, 448000),
#   'Song_name': '感電',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 264,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 19, 28, 55, 888000),
#   'Song_name': '打上花火',
#   'Artist': 'Daoko',
#   'Length': 289,
#   'Genres': ['j-pixie', 'japanese electropop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 19, 1, 1, 391000),
#   'Song_name': 'KICK BACK',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 193,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 47, 31, 149000),
#   'Song_name': 'Forgery',
#   'Artist': 'yupsilon',
#   'Length': 140,
#   'Genres': []},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 45, 9, 785000),
#   'Song_name': 'Last Dance',
#   'Artist': 'Eve',
#   'Length': 240,
#   'Genres': ['anime', 'anime rock']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 41, 8, 672000),
#   'Song_name': 'Flamingo',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 196,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 37, 51, 906000),
#   'Song_name': 'veil',
#   'Artist': '須田景凪',
#   'Length': 209,
#   'Genres': ['japanese teen pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 34, 21, 544000),
#   'Song_name': '愛を解く',
#   'Artist': 'yama',
#   'Length': 181,
#   'Genres': ['j-pop', 'japanese teen pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 31, 20, 58000),
#   'Song_name': '聖者の行進',
#   'Artist': 'キタニタツヤ',
#   'Length': 177,
#   'Genres': ['j-pop', 'japanese electropop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 28, 21, 970000),
#   'Song_name': 'Neppa',
#   'Artist': 'tephe',
#   'Length': 74,
#   'Genres': []},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 27, 7, 26000),
#   'Song_name': '死神',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 180,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 24, 5, 756000),
#   'Song_name': '怪物',
#   'Artist': 'YOASOBI',
#   'Length': 205,
#   'Genres': ['j-pop', 'japanese teen pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 20, 39, 195000),
#   'Song_name': 'Yoruwahonoka',
#   'Artist': 'Eve',
#   'Length': 193,
#   'Genres': ['anime', 'anime rock']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 17, 24, 584000),
#   'Song_name': 'Rendezvous',
#   'Artist': 'Kanaria',
#   'Length': 132,
#   'Genres': ['vocaloid']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 15, 12, 243000),
#   'Song_name': '化け猫 - Leaks From His Laptop',
#   'Artist': 'キタニタツヤ',
#   'Length': 56,
#   'Genres': ['j-pop', 'japanese electropop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 16, 14, 15, 832000),
#   'Song_name': 'KICK BACK',
#   'Artist': 'Kenshi Yonezu',
#   'Length': 193,
#   'Genres': ['anime', 'j-pop']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 15, 50, 19, 113000),
#   'Song_name': 'I Like You (A Happier Song) (with Doja Cat)',
#   'Artist': 'Post Malone',
#   'Length': 192,
#   'Genres': ['dfw rap', 'melodic rap', 'rap']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 15, 47, 5, 514000),
#   'Song_name': 'Gasoline',
#   'Artist': 'Nic D',
#   'Length': 103,
#   'Genres': ['pop', 'pop rap']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 15, 45, 22, 197000),
#   'Song_name': 'Buddy',
#   'Artist': 'Connor Price',
#   'Length': 117,
#   'Genres': []},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 15, 43, 23, 496000),
#   'Song_name': 'Good Luck',
#   'Artist': 'Abhi The Nomad',
#   'Length': 135,
#   'Genres': ['desi hip hop', 'indie r&b', 'pop rap']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 15, 41, 7, 602000),
#   'Song_name': 'Perfect',
#   'Artist': 'Logic',
#   'Length': 100,
#   'Genres': ['conscious hip hop', 'dmv rap', 'hip hop', 'pop rap', 'rap']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 15, 39, 27, 73000),
#   'Song_name': 'Godzilla (feat. Juice WRLD)',
#   'Artist': 'Eminem',
#   'Length': 210,
#   'Genres': ['detroit hip hop', 'hip hop', 'rap']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 15, 35, 55, 445000),
#   'Song_name': "THAT'S A JOKE",
#   'Artist': 'NF',
#   'Length': 229,
#   'Genres': ['hip hop', 'pop rap', 'rap']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 14, 23, 26, 403000),
#   'Song_name': 'Merry Christmas',
#   'Artist': 'Anne Shelton',
#   'Length': 138,
#   'Genres': ['british dance band', 'deep adult standards']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 14, 22, 38, 552000),
#   'Song_name': "Rockin' Around The Christmas Tree",
#   'Artist': 'Brenda Lee',
#   'Length': 126,
#   'Genres': ['adult standards', 'lounge']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 14, 20, 31, 549000),
#   'Song_name': 'Silver And Gold - From "Rudolph The Red-Nosed Reindeer" Soundtrack',
#   'Artist': 'Burl Ives',
#   'Length': 106,
#   'Genres': ['adult standards', 'american folk revival']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 13, 32, 10, 707000),
#   'Song_name': 'Mistletoe And Holly - Remastered 1999',
#   'Artist': 'Frank Sinatra',
#   'Length': 136,
#   'Genres': ['adult standards', 'easy listening', 'lounge']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 13, 29, 54, 359000),
#   'Song_name': 'Silver Bells',
#   'Artist': 'Doris Day',
#   'Length': 162,
#   'Genres': ['adult standards', 'easy listening', 'lounge', 'vocal jazz']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 13, 27, 10, 967000),
#   'Song_name': 'Here We Come a-Caroling / We Wish You a Merry Christmas',
#   'Artist': 'Perry Como',
#   'Length': 94,
#   'Genres': ['adult standards', 'easy listening', 'lounge']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 13, 25, 36, 567000),
#   'Song_name': 'Little Jack Frost Get Lost (with Marjorie Hughes) - 78rpm Version',
#   'Artist': 'Frankie Carle',
#   'Length': 164,
#   'Genres': ['big band', 'honky-tonk piano', 'space age pop', 'swing']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 12, 52, 16, 52000),
#   'Song_name': "I'd Like To Trim A Tree With",
#   'Artist': 'The McGuire Sisters',
#   'Length': 117,
#   'Genres': ['adult standards',
#    'deep adult standards',
#    'doo-wop',
#    'easy listening',
#    'lounge',
#    'vocal harmony group']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 12, 50, 17, 907000),
#   'Song_name': 'Warm December - Remastered 1992',
#   'Artist': 'Julie London',
#   'Length': 118,
#   'Genres': ['adult standards',
#    'easy listening',
#    'lounge',
#    'soul',
#    'torch song',
#    'vocal jazz']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 12, 48, 18, 806000),
#   'Song_name': 'A Holly Jolly Christmas',
#   'Artist': 'Burl Ives',
#   'Length': 135,
#   'Genres': ['adult standards', 'american folk revival']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 12, 46, 2, 762000),
#   'Song_name': "(There's No Place Like) Home for the Holidays - 1959 Version",
#   'Artist': 'Perry Como',
#   'Length': 175,
#   'Genres': ['adult standards', 'easy listening', 'lounge']},
#  {'Played_Time': datetime.datetime(2023, 3, 20, 10, 21, 4, 736000),
#   'Song_name': 'Hi Bully',
#   'Artist': 'Touched',
#   'Length': 204,
#   'Genres': []}]

# %%
len(result['items'])
# Out:
# 50

# %%
result['items'][0]['track']['artists'][0]['id']
# Out:
# '1snhtMLeb2DYoMOcVbb8iB'

# %%
kenshi = '1snhtMLeb2DYoMOcVbb8iB'

# %%
test = sp.artist(kenshi)

# %%
test['genres']
# Out:
# ['anime', 'j-pop']
